# %%
import pandas as pd

weight = pd.read_pickle("weight.pkl.gz")

# %%
weight
# Out:
#                      weightPounds   BMI  bodyFatPCT  bodyWaterPCT  \
# timeStamp
# 2021-01-10 04:52:40        178.88  24.2        25.4          54.5
# 2021-01-10 06:14:33        179.28  24.3        24.5          55.1
# 2021-01-10 11:44:55         178.6  24.2        24.3          55.3
# 2021-01-10 12:04:49        178.46  24.2        22.9          56.3
# 2021-01-11 05:03:12        178.95  24.2        25.2          54.6
# ...                           ...   ...         ...           ...
# 2021-12-14 07:04:09        182.39  24.7        <NA>          <NA>
# 2021-12-15 03:45:03        181.04  24.5        27.1          53.2
# 2021-12-15 05:08:28        180.71  24.5        27.3          53.0
# 2021-12-15 08:14:48        180.76  24.5        25.5          54.4
# 2021-12-16 04:09:26        181.18  24.5        26.5          53.7
#
#                      boneMassPounds  muscleMassPounds
# timeStamp
# 2021-01-10 04:52:40             8.9             69.64
# ...
